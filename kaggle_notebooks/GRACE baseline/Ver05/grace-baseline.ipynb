# %% [markdown]
# # 🛡️ GRACE: Automated Software Vulnerability Detection via In-Context Learning & Graph Similarity
#
# **Sổ Tay Tái Tạo Kỹ Thuật Cho Môi Trường GPU Kaggle (v1.0.0)**
#
# Sổ tay này triển khai tự động quy trình thử nghiệm phát hiện lỗ hổng phần mềm trên 2 tập dữ liệu benchmark thực tế: **Devign** (`DetectVul/devign`) và **Reveal** (`SensorLLM/Reveal`) bằng việc kết hợp:
# 1. **Stage 1**: Tự động chuẩn hóa dữ liệu & bóc tách mẫu cân bằng nhãn (**Stratified Slicing**).
# 2. **Stage 2**: Trích xuất đặc trưng với **CodeT5**, tính ma trận khoảng cách $L_2$, & lựa chọn mẫu ví dụ tối ưu theo công thức **Hybrid Reranking** ($0.7 \times \text{Jaccard} + 0.3 \times \text{GraphSim}$).
# 3. **Stage 3**: Lắp ráp câu lệnh dẫn hướng theo **Figure 6**, bóc tách nhãn với Parser Regex 4 tầng & bảo vệ tiến trình tuyệt đối bằng **JSONL Realtime Checkpointing**.
# 4. **Stage 4 & 5**: Đo lường trọn vẹn chỉ số **F1-Score, Precision, Recall** và xuất báo cáo nghiệm thu tự động.
#
# ---

# %% [markdown]
# ## Bước 0: Thiết Lập Thư Mục Làm Việc Từ Dataset Đầu Vào (Dataset Setup)
# Sao chép bộ mã nguồn từ thư mục Read-Only (`/kaggle/input/datasets/huuhieu3333/grace-source-code` hoặc `/kaggle/input/grace-source-code`) sang thư mục có quyền Ghi (`/kaggle/working/GRACE`) và chuyển thư mục làm việc.

# %%
import os, shutil

# 1. Tự động quét và tìm chính xác thư mục chứa run_pipeline.py trong /kaggle/input
found_src_dir = None
for root, dirs, files in os.walk('/kaggle/input'):
    if 'run_pipeline.py' in files:
        found_src_dir = root
        break

dest_dir = '/kaggle/working/GRACE'
if os.path.exists(dest_dir):
    shutil.rmtree(dest_dir)

if found_src_dir:
    print(f'[*] Tìm thấy mã nguồn tại: {found_src_dir}')
    shutil.copytree(found_src_dir, dest_dir)
    print(f'✓ [OK] Đã sao chép toàn bộ mã nguồn sang: {dest_dir}')
else:
    print('[!] ERROR: Không tìm thấy file run_pipeline.py trong /kaggle/input!')

# 2. Chuyển thư mục làm việc về /kaggle/working/GRACE
# %cd /kaggle/working/GRACE
# !ls -la
# Out:
# [*] Tìm thấy mã nguồn tại: /kaggle/input/datasets/huuhieu3333/grace-source-code/GRACE
# ✓ [OK] Đã sao chép toàn bộ mã nguồn sang: /kaggle/working/GRACE
# /kaggle/working/GRACE
# total 80
# drwxr-xr-x 3 root root  4096 Aug 21 00:28 .
# drwxr-xr-x 3 root root  4096 Aug 21 00:40 ..
# -rw-r--r-- 1 root root  3717 Aug 21 00:28 config.py
# drwxr-xr-x 3 root root  4096 Aug 21 00:28 data
# -rw-r--r-- 1 root root  6983 Aug 21 00:28 data_loader.py
# -rw-r--r-- 1 root root 11850 Aug 21 00:28 evaluator.py
# -rw-r--r-- 1 root root  8187 Aug 21 00:28 GRACE_Kaggle_Reproduce.ipynb
# -rw-r--r-- 1 root root  3525 Aug 21 00:28 metrics.py
# -rw-r--r-- 1 root root  5282 Aug 21 00:28 prompt_engine.py
# -rw-r--r-- 1 root root   363 Aug 21 00:28 requirements.txt
# -rw-r--r-- 1 root root  9170 Aug 21 00:28 retrieval_engine.py
# -rw-r--r-- 1 root root  8022 Aug 21 00:28 run_pipeline.py

# %% [markdown]
# ## Bước 1: Chuẩn Bị Môi Trường & Thư Viện (Environment Setup)
# Cài đặt các gói phụ thuộc cơ bản theo chuẩn `requirements.txt`.

# %%
# !pip install -q -r requirements.txt
print('✓ [Setup Complete] Các thư viện phụ thuộc đã sẵn sàng trên Kaggle!')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 49.0 MB/s eta 0:00:00
# ✓ [Setup Complete] Các thư viện phụ thuộc đã sẵn sàng trên Kaggle!

# %% [markdown]
# ### Xác Minh Kết Nối Kaggle Secrets
# Kiểm tra xem notebook đã được cấp quyền đọc `FPT_API_KEY` và `FPT_BASE_URL` từ Kaggle Secrets chưa.

# %%
from kaggle_secrets import UserSecretsClient
try:
    user_secrets = UserSecretsClient()
    api_key = user_secrets.get_secret('FPT_API_KEY')
    base_url = user_secrets.get_secret('FPT_BASE_URL')
    print(f'✓ [OK] Đã nạp thành công FPT_API_KEY ({api_key[:6]}...) và FPT_BASE_URL ({base_url})!')
except Exception as e:
    print(f'[!] Cảnh báo nạp Secret: {e}. Vui lòng kiểm tra Add-ons -> Secrets trên Kaggle.')
# Out:
# ✓ [OK] Đã nạp thành công FPT_API_KEY (sk-Kbz...) và FPT_BASE_URL (https://mkp-api.fptcloud.com)!

# %% [markdown]
# ## Bước 2: Chạy Kiểm Thử Khảo Sát Tinh gọn (Warm-up Dry-Run)
# Chạy thử nghiệm E2E chế độ Mock trên 10% dữ liệu để xác minh toàn bộ luồng đường ống hoạt động mượt mà.

# %%
# !python run_pipeline.py --use_mock --sample_ratio 0.1 --experiment_name kaggle_warmup_dryrun
# Out:
# 2026-08-21 00:41:20,644 - INFO - Chế độ Mock được kích hoạt: Khởi tạo dữ liệu giả lập chất lượng cao...
# 2026-08-21 00:41:20,644 - INFO - Hoàn tất chuẩn bị dữ liệu -> Train index: 50 mẫu | Test eval: 20 mẫu.
# 2026-08-21 00:41:59,634 - INFO - NumExpr defaulting to 4 threads.
# 2026-08-21 00:42:01,642 - INFO - Đang nạp mô hình Salesforce/codet5-base trên thiết bị cuda...
# 2026-08-21 00:42:01,829 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 00:42:01,829 - WARNING - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 00:42:01,839 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/config.json "HTTP/1.1 200 OK"
# 2026-08-21 00:42:01,850 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/config.json "HTTP/1.1 200 OK"
#
# ###########################################################################
# ###  GRACE VULNERABILITY DETECTION - END-TO-END ORCHESTRATION PIPELINE  ###
# ###########################################################################
# [*] Experiment Name  : kaggle_warmup_dryrun
# [*] Target Dataset   : DetectVul/devign (Sample Ratio: 10.0%)
# [*] Execution Mode   : Mock/Local Test (CPU/Fast)
# [*] Checkpoint Dir   : /kaggle/working/checkpoints
# [*] Output Dir       : /kaggle/working/output
# ===========================================================================
#
# >>> [PHASE 1] NẠP DỮ LIỆU & BÓC TÁCH MẨU KHẢO SÁT CÂN BẰNG NHÃN (STRATIFIED SLICING)...
#
# >>> [PHASE 2] XÂY DỰNG INDEX L2 & GÁN MẪU VÍ DỤ DEMONSTRATION (HYBRID RERANKING)...
# config.json: 1.57kB [00:00, 4.11MB/s]
# 2026-08-21 00:42:01,960 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:42:01,971 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-08-21 00:42:01,981 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 1.48kB [00:00, 5.27MB/s]
# 2026-08-21 00:42:02,086 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:42:02,095 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-08-21 00:42:02,200 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-08-21 00:42:02,305 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-08-21 00:42:02,416 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/tokenizer.json "HTTP/1.1 404 Not Found"
# 2026-08-21 00:42:02,554 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/tokenizer.model "HTTP/1.1 404 Not Found"
# 2026-08-21 00:42:02,656 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/added_tokens.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:42:02,667 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/added_tokens.json "HTTP/1.1 200 OK"
# 2026-08-21 00:42:02,679 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/added_tokens.json "HTTP/1.1 200 OK"
# added_tokens.json: 100%|█████████████████████| 2.00/2.00 [00:00<00:00, 11.2kB/s]
# 2026-08-21 00:42:02,834 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:42:02,845 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/special_tokens_map.json "HTTP/1.1 200 OK"
# 2026-08-21 00:42:02,855 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/special_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 12.5kB [00:00, 48.1MB/s]
# 2026-08-21 00:42:02,958 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# 2026-08-21 00:42:03,072 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:42:03,083 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-08-21 00:42:03,194 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-08-21 00:42:03,300 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-08-21 00:42:03,410 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:42:03,419 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/vocab.json "HTTP/1.1 200 OK"
# 2026-08-21 00:42:03,431 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/vocab.json "HTTP/1.1 200 OK"
# vocab.json: 703kB [00:00, 42.1MB/s]
# 2026-08-21 00:42:03,549 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:42:03,559 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/merges.txt "HTTP/1.1 200 OK"
# 2026-08-21 00:42:03,571 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/merges.txt "HTTP/1.1 200 OK"
# merges.txt: 294kB [00:00, 85.5MB/s]
# 2026-08-21 00:42:03,645 - WARNING - Không thể nạp CodeT5 (extra_special_tokens must be a list/tuple of str or AddedToken, or a dict mapping names to tokens). Chuyển sang Offline TF-IDF Embedder...
# 2026-08-21 00:42:03,665 - INFO - Đang xây dựng Index cho 50 mẫu huấn luyện...
# 2026-08-21 00:42:03,689 - INFO - Xây dựng xong Index ma trận vector với kích thước: (50, 59)
# 2026-08-21 00:42:03,689 - INFO - Đang tiến hành truy xuất và gán mẫu In-Context Demonstration cho 20 mẫu Test...
# 2026-08-21 00:42:03,705 - INFO - Hoàn tất quy trình Retrieval Engine. Tự động gán trường 'example' cho 100% mẫu kiểm thử.
# 2026-08-21 00:42:03,705 - INFO - Môi trường Local/Test: Kích hoạt chế độ Intelligent Mock LLM Evaluator để test tốc độ cao.
# 2026-08-21 00:42:03,705 - INFO - Khởi tạo phiên chạy mới. File Checkpoint mới sẽ được lưu tại: /kaggle/working/checkpoints/checkpoint_kaggle_warmup_dryrun.jsonl
# 2026-08-21 00:42:03,705 - INFO - Bắt đầu quy trình Đánh Giá (Evaluator) cho 20 mẫu [Experiment: kaggle_warmup_dryrun]...
#
# >>> [PHASE 3] THỰC THI SUY LUẬN AI EVALUATOR & TỰ PHỤC HỒI CHECKPOINTING...
# Acc: 50.0% | ID: mock_19: 100%|█████████████| 20/20 [00:00<00:00, 42.32sample/s]
# 2026-08-21 00:42:04,179 - INFO - [✓] Đã xuất báo cáo chi tiết định dạng JSON tại: /kaggle/working/output/results_kaggle_warmup_dryrun.json
# 2026-08-21 00:42:04,179 - INFO - [✓] Đã xuất báo cáo đối chiếu nhãn CSV tại: /kaggle/working/output/summary_kaggle_warmup_dryrun.csv
#
# >>> [PHASE 4] ĐO LƯỜNG CHỈ SỐ AN NINH MẠNG & XUẤT BÁO CÁO NGHIỆM THU...
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# |  BẢNG BÁO CÁO KẾT QUẢ ĐÁNH GIÁ GRACE - [Mock Dry-Run E2E    ]  |
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# | - Tổng số mẫu đánh giá (Total Samples): 20                      |
# | - F1-SCORE (Chỉ số quyết định):         0.6667                  |
# | - Precision (Độ chính xác báo lỗi):     0.5                     |
# | - Recall (Độ phủ phát hiện lỗ hổng):    1.0                     |
# | - Accuracy (Tỉ lệ đúng toàn cục):       0.5                     |
# -----------------------------------------------------------------
# | MA TRẬN NHẦM LẪN (CONFUSION MATRIX):                              |
# |   [+] True Positive  (Đoán đúng Có lỗi):  10                    |
# |   [-] False Negative (Bỏ sót Lỗ hổng):   0                     |
# |   [+] True Negative  (Đoán đúng An toàn): 0                     |
# |   [-] False Positive (Báo động Giả):      10                    |
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# ===========================================================================
# 🎉 HOÀN THÀNH QUY TRÌNH GRACE END-TO-END PIPELINE! (Thời gian tổng: 0.73 phút)
# ===========================================================================

# %% [markdown]
# ## Bước 3: Khởi Chạy Thực Nghiệm Trí Tuệ Nhân Tạo Trên Bộ Dữ Liệu DEVIGN
# Kết nối tới **FPT AI Factory API** (DeepSeek-V4-Flash) để đánh giá lỗ hổng bảo mật trên 5% dataset thực tế **DetectVul/devign**.
#
# *(Lưu ý: Bạn cần khai báo biến `FPT_API_KEY` và `FPT_BASE_URL` trong Kaggle Secrets (Add-ons -> Secrets) trước khi chạy. Nhờ cơ chế Checkpointing JSONL, nếu phiên làm việc bị timeout, bạn chỉ cần bấm chạy lại cell này, hệ thống sẽ tiếp tục tại đúng mẫu trước đó!)*

# %%
# !python run_pipeline.py --dataset DetectVul/devign --sample_ratio 0.05 --experiment_name devign_openweights_5pct
# Out:
# 2026-08-21 00:42:07,997 - INFO - Đang kết nối tải dataset 'DetectVul/devign' từ Hugging Face Hub...
# 2026-08-21 00:42:07,998 - INFO - Phát hiện file dữ liệu đã trích xuất đồ thị CPG cục bộ: data/processed/devign_train_processed.json. Đang nạp...
# 2026-08-21 00:42:48,424 - INFO - Nạp thành công 21854 mẫu đã có đầy đủ đồ thị Joern từ devign_train_processed.json.
# 2026-08-21 00:42:49,098 - INFO - Trích xuất 5.0% dataset: Tổng 1091 mẫu (500 Vulnerable, 591 Safe) từ gốc 21854 mẫu.
# 2026-08-21 00:42:51,713 - INFO - Phát hiện file dữ liệu đã trích xuất đồ thị CPG cục bộ: data/processed/devign_test_processed.json. Đang nạp...
# 2026-08-21 00:42:55,934 - INFO - Nạp thành công 2732 mẫu đã có đầy đủ đồ thị Joern từ devign_test_processed.json.
# 2026-08-21 00:42:55,939 - INFO - Trích xuất 5.0% dataset: Tổng 135 mẫu (62 Vulnerable, 73 Safe) từ gốc 2732 mẫu.
# 2026-08-21 00:42:56,209 - INFO - Hoàn tất chuẩn bị dữ liệu -> Train index: 1091 mẫu | Test eval: 135 mẫu.
# 2026-08-21 00:43:03,371 - INFO - NumExpr defaulting to 4 threads.
# 2026-08-21 00:43:04,068 - INFO - Đang nạp mô hình Salesforce/codet5-base trên thiết bị cuda...
# 2026-08-21 00:43:04,274 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:43:04,284 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/config.json "HTTP/1.1 200 OK"
# 2026-08-21 00:43:04,390 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 00:43:04,390 - WARNING - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 00:43:04,399 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-08-21 00:43:04,500 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:43:04,509 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-08-21 00:43:04,612 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-08-21 00:43:04,719 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-08-21 00:43:04,826 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 00:43:04,836 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-08-21 00:43:04,941 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-08-21 00:43:05,047 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-08-21 00:43:05,091 - WARNING - Không thể nạp CodeT5 (extra_special_tokens must be a list/tuple of str or AddedToken, or a dict mapping names to tokens). Chuyển sang Offline TF-IDF Embedder...
# 2026-08-21 00:43:05,099 - INFO - Đang xây dựng Index cho 1091 mẫu huấn luyện...
# 2026-08-21 00:43:05,365 - INFO - Xây dựng xong Index ma trận vector với kích thước: (1091, 256)
# 2026-08-21 00:43:05,365 - INFO - Đang tiến hành truy xuất và gán mẫu In-Context Demonstration cho 135 mẫu Test...
# 2026-08-21 00:43:05,975 - INFO - Hoàn tất quy trình Retrieval Engine. Tự động gán trường 'example' cho 100% mẫu kiểm thử.
# 2026-08-21 00:43:07,736 - INFO - Kết nối tới API: https://mkp-api.fptcloud.com với model gemma-4-26B-A4B-it...
# 2026-08-21 00:43:07,779 - INFO - Khởi tạo phiên chạy mới. File Checkpoint mới sẽ được lưu tại: /kaggle/working/checkpoints/checkpoint_devign_openweights_5pct.jsonl
# 2026-08-21 00:43:07,780 - INFO - Bắt đầu quy trình Đánh Giá (Evaluator) cho 135 mẫu [Experiment: devign_openweights_5pct]...
#
# ###########################################################################
# ###  GRACE VULNERABILITY DETECTION - END-TO-END ORCHESTRATION PIPELINE  ###
# ###########################################################################
# [*] Experiment Name  : devign_openweights_5pct
# [*] Target Dataset   : DetectVul/devign (Sample Ratio: 5.0%)
# [*] Execution Mode   : Full Open-Weights LLM (gemma-4-26B-A4B-it on GPU)
# [*] Checkpoint Dir   : /kaggle/working/checkpoints
# [*] Output Dir       : /kaggle/working/output
# ===========================================================================
#
# >>> [PHASE 1] NẠP DỮ LIỆU & BÓC TÁCH MẨU KHẢO SÁT CÂN BẰNG NHÃN (STRATIFIED SLICING)...
#
# >>> [PHASE 2] XÂY DỰNG INDEX L2 & GÁN MẪU VÍ DỤ DEMONSTRATION (HYBRID RERANKING)...
#
# >>> [PHASE 3] THỰC THI SUY LUẬN AI EVALUATOR & TỰ PHỤC HỒI CHECKPOINTING...
# Evaluating:   0%|                                   | 0/135 [00:00<?, ?sample/s]2026-08-21 00:43:08,943 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 100.0% | ID: id_25566:   1%|           | 1/135 [00:01<02:38,  1.18s/sample]2026-08-21 00:43:09,315 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 50.0% | ID: id_15373:   1%|▏           | 2/135 [00:01<01:32,  1.43sample/s]2026-08-21 00:43:10,450 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 33.3% | ID: id_11988:   2%|▎           | 3/135 [00:02<01:58,  1.11sample/s]2026-08-21 00:43:10,840 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 50.0% | ID: id_2820_:   3%|▎           | 4/135 [00:03<01:31,  1.44sample/s]2026-08-21 00:43:11,236 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 60.0% | ID: id_11328:   4%|▍           | 5/135 [00:03<01:16,  1.70sample/s]2026-08-21 00:43:11,705 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 50.0% | ID: id_686_l:   4%|▌           | 6/135 [00:03<01:10,  1.83sample/s]2026-08-21 00:43:12,128 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 57.1% | ID: id_4879_:   5%|▌           | 7/135 [00:04<01:04,  1.97sample/s]2026-08-21 00:43:12,827 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 62.5% | ID: id_9301_:   6%|▋           | 8/135 [00:05<01:12,  1.76sample/s]2026-08-21 00:43:13,344 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 66.7% | ID: id_14024:   7%|▊           | 9/135 [00:05<01:09,  1.81sample/s]2026-08-21 00:43:13,725 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 70.0% | ID: id_18044:   7%|▊          | 10/135 [00:05<01:02,  2.00sample/s]2026-08-21 00:43:14,220 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 63.6% | ID: id_12142:   8%|▉          | 11/135 [00:06<01:01,  2.01sample/s]2026-08-21 00:43:14,643 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 58.3% | ID: id_23872:   9%|▉          | 12/135 [00:06<00:58,  2.10sample/s]2026-08-21 00:43:14,944 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 53.8% | ID: id_9231_:  10%|█          | 13/135 [00:07<00:51,  2.37sample/s]2026-08-21 00:43:15,314 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc:
- INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 55.7% | ID: id_25310:  97%|█████████▋| 131/135 [02:05<00:02,  1.91sample/s]2026-08-21 00:45:13,307 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 55.3% | ID: id_2832_:  98%|█████████▊| 132/135 [02:05<00:01,  2.11sample/s]2026-08-21 00:45:13,641 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 55.6% | ID: id_20433:  99%|█████████▊| 133/135 [02:05<00:00,  2.32sample/s]2026-08-21 00:45:14,013 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 56.0% | ID: id_12329:  99%|█████████▉| 134/135 [02:06<00:00,  2.42sample/s]2026-08-21 00:45:14,321 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 55.6% | ID: id_24141: 100%|██████████| 135/135 [02:06<00:00,  1.07sample/s]
# 2026-08-21 00:45:14,328 - INFO - [✓] Đã xuất báo cáo chi tiết định dạng JSON tại: /kaggle/working/output/results_devign_openweights_5pct.json
# 2026-08-21 00:45:14,328 - INFO - [✓] Đã xuất báo cáo đối chiếu nhãn CSV tại: /kaggle/working/output/summary_devign_openweights_5pct.csv
#
# >>> [PHASE 4] ĐO LƯỜNG CHỈ SỐ AN NINH MẠNG & XUẤT BÁO CÁO NGHIỆM THU...
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# |  BẢNG BÁO CÁO KẾT QUẢ ĐÁNH GIÁ GRACE - [DetectVul/devign    ]  |
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# | - Tổng số mẫu đánh giá (Total Samples): 135                     |
# | - F1-SCORE (Chỉ số quyết định):         0.4643                  |
# | - Precision (Độ chính xác báo lỗi):     0.52                    |
# | - Recall (Độ phủ phát hiện lỗ hổng):    0.4194                  |
# | - Accuracy (Tỉ lệ đúng toàn cục):       0.5556                  |
# -----------------------------------------------------------------
# | MA TRẬN NHẦM LẪN (CONFUSION MATRIX):                              |
# |   [+] True Positive  (Đoán đúng Có lỗi):  26                    |
# |   [-] False Negative (Bỏ sót Lỗ hổng):   36                    |
# |   [+] True Negative  (Đoán đúng An toàn): 49                    |
# |   [-] False Positive (Báo động Giả):      24                    |
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# ===========================================================================
# 🎉 HOÀN THÀNH QUY TRÌNH GRACE END-TO-END PIPELINE! (Thời gian tổng: 3.11 phút)
# ===========================================================================

# %% [markdown]
# ## Bước 4: Khởi Chạy Thực Nghiệm Mở Rộng Trên Bộ Dữ Liệu REVEAL
# Thử nghiệm trên bộ dataset Reveal nhằm kiểm chứng khả năng tổng quát hóa (Generalizability) của phương pháp GRACE.

# %% [markdown]
# ## Bước 5: Phỏng Đoán Báo Cáo Kết Quả Tự Động Xuất Xưởng (Artifact Inspection)
# Trình diễn các file kết quả JSON và CSV đã được ghi xuống thư mục `output/`.

# %%
import os
import pandas as pd
from pathlib import Path

output_dir = Path('/kaggle/working/output') if os.path.exists('/kaggle/working') else Path('./output')
print('Danh sách tệp nghiệm thu thu được từ hệ thống:')
if output_dir.exists():
    for f in output_dir.glob('*.*'):
        print('  ->', f.name)
else:
    print('Thư mục output chưa được tạo.')
# Out:
# Danh sách tệp nghiệm thu thu được từ hệ thống:
#   -> summary_kaggle_warmup_dryrun.csv
#   -> results_kaggle_warmup_dryrun.json
#   -> results_devign_openweights_5pct.json
#   -> summary_devign_openweights_5pct.csv
