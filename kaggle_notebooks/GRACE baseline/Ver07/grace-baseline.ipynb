# %% [markdown]
# # 🛡️ GRACE: Automated Software Vulnerability Detection via In-Context Learning & Graph Similarity
#
# **Sổ Tay Tái Tạo Kỹ Thuật Cho Môi Trường GPU Kaggle (v1.0.0)**
#
# Sổ tay này triển khai tự động quy trình thử nghiệm phát hiện lỗ hổng phần mềm trên 2 tập dữ liệu benchmark thực tế: **Devign** (`DetectVul/devign`) và **Reveal** (`SensorLLM/Reveal`) bằng việc kết hợp:
# 1. **Stage 1**: Tự động chuẩn hóa dữ liệu & bóc tách mẫu cân bằng nhãn (**Stratified Slicing**).
# 2. **Stage 2**: Trích xuất đặc trưng với **CodeT5**, tính ma trận khoảng cách $L_2$, & lựa chọn mẫu ví dụ tối ưu theo công thức **Hybrid Reranking** ($0.7 \times \text{Jaccard} + 0.3 \times \text{GraphSim}$).
# 3. **Stage 3**: Lắp ráp câu lệnh dẫn hướng theo **Figure 6**, bóc tách nhãn với Parser Regex 4 tầng & bảo vệ tiến trình tuyệt đối bằng **JSONL Realtime Checkpointing**.
# 4. **Stage 4 & 5**: Đo lường trọn vẹn chỉ số **F1-Score, Precision, Recall** và xuất báo cáo nghiệm thu tự động.
#
# ---

# %% [markdown]
# ## Bước 0: Thiết Lập Thư Mục Làm Việc Từ Dataset Đầu Vào (Dataset Setup)
# Sao chép bộ mã nguồn từ thư mục Read-Only (`/kaggle/input/datasets/huuhieu3333/grace-source-code` hoặc `/kaggle/input/grace-source-code`) sang thư mục có quyền Ghi (`/kaggle/working/GRACE`) và chuyển thư mục làm việc.

# %%
import os, shutil

# 1. Tự động quét và tìm chính xác thư mục chứa run_pipeline.py trong /kaggle/input
found_src_dir = None
for root, dirs, files in os.walk('/kaggle/input'):
    if 'run_pipeline.py' in files:
        found_src_dir = root
        break

dest_dir = '/kaggle/working/GRACE'
if os.path.exists(dest_dir):
    shutil.rmtree(dest_dir)

if found_src_dir:
    print(f'[*] Tìm thấy mã nguồn tại: {found_src_dir}')
    shutil.copytree(found_src_dir, dest_dir)
    print(f'✓ [OK] Đã sao chép toàn bộ mã nguồn sang: {dest_dir}')
else:
    print('[!] ERROR: Không tìm thấy file run_pipeline.py trong /kaggle/input!')

# 2. Chuyển thư mục làm việc về /kaggle/working/GRACE
# %cd /kaggle/working/GRACE
# !ls -la
# Out:
# [*] Tìm thấy mã nguồn tại: /kaggle/input/datasets/huuhieu3333/grace-source-code/GRACE
# ✓ [OK] Đã sao chép toàn bộ mã nguồn sang: /kaggle/working/GRACE
# /kaggle/working/GRACE
# total 80
# drwxr-xr-x 3 root root  4096 Aug 21 02:50 .
# drwxr-xr-x 3 root root  4096 Aug 21 02:51 ..
# -rw-r--r-- 1 root root  3717 Aug 21 02:50 config.py
# drwxr-xr-x 3 root root  4096 Aug 21 02:50 data
# -rw-r--r-- 1 root root  6983 Aug 21 02:50 data_loader.py
# -rw-r--r-- 1 root root 12245 Aug 21 02:50 evaluator.py
# -rw-r--r-- 1 root root  7954 Aug 21 02:50 GRACE_Kaggle_Reproduce.ipynb
# -rw-r--r-- 1 root root  3525 Aug 21 02:50 metrics.py
# -rw-r--r-- 1 root root  5282 Aug 21 02:50 prompt_engine.py
# -rw-r--r-- 1 root root   363 Aug 21 02:50 requirements.txt
# -rw-r--r-- 1 root root 12267 Aug 21 02:50 retrieval_engine.py
# -rw-r--r-- 1 root root  8022 Aug 21 02:50 run_pipeline.py

# %% [markdown]
# ## Bước 1: Chuẩn Bị Môi Trường & Thư Viện (Environment Setup)
# Cài đặt các gói phụ thuộc cơ bản theo chuẩn `requirements.txt`.

# %%
# !pip install -q -r requirements.txt
print('✓ [Setup Complete] Các thư viện phụ thuộc đã sẵn sàng trên Kaggle!')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 53.1 MB/s eta 0:00:00
# ✓ [Setup Complete] Các thư viện phụ thuộc đã sẵn sàng trên Kaggle!

# %% [markdown]
# ### Xác Minh Kết Nối Kaggle Secrets
# Kiểm tra xem notebook đã được cấp quyền đọc `FPT_API_KEY` và `FPT_BASE_URL` từ Kaggle Secrets chưa.

# %%
from kaggle_secrets import UserSecretsClient
try:
    user_secrets = UserSecretsClient()
    api_key = user_secrets.get_secret('FPT_API_KEY')
    base_url = user_secrets.get_secret('FPT_BASE_URL')
    print(f'✓ [OK] Đã nạp thành công FPT_API_KEY ({api_key[:6]}...) và FPT_BASE_URL ({base_url})!')
except Exception as e:
    print(f'[!] Cảnh báo nạp Secret: {e}. Vui lòng kiểm tra Add-ons -> Secrets trên Kaggle.')
# Out:
# ✓ [OK] Đã nạp thành công FPT_API_KEY (sk-Kbz...) và FPT_BASE_URL (https://mkp-api.fptcloud.com)!

# %% [markdown]
# ## Bước 2: Chạy Kiểm Thử Khảo Sát Tinh gọn (Warm-up Dry-Run)
# Chạy thử nghiệm E2E chế độ Mock trên 10% dữ liệu để xác minh toàn bộ luồng đường ống hoạt động mượt mà.

# %%
# !python run_pipeline.py --use_mock --sample_ratio 0.1 --experiment_name kaggle_warmup_dryrun
# Out:
# 2026-08-21 02:52:31,334 - INFO - Chế độ Mock được kích hoạt: Khởi tạo dữ liệu giả lập chất lượng cao...
# 2026-08-21 02:52:31,334 - INFO - Hoàn tất chuẩn bị dữ liệu -> Train index: 50 mẫu | Test eval: 20 mẫu.
# 2026-08-21 02:52:57,957 - INFO - NumExpr defaulting to 4 threads.
# 2026-08-21 02:52:59,165 - INFO - Đang nạp mô hình Salesforce/codet5-base trên thiết bị cuda...
# 2026-08-21 02:52:59,353 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 02:52:59,369 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/vocab.json "HTTP/1.1 200 OK"
# 2026-08-21 02:52:59,387 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/vocab.json "HTTP/1.1 200 OK"
#
# ###########################################################################
# ###  GRACE VULNERABILITY DETECTION - END-TO-END ORCHESTRATION PIPELINE  ###
# ###########################################################################
# [*] Experiment Name  : kaggle_warmup_dryrun
# [*] Target Dataset   : DetectVul/devign (Sample Ratio: 10.0%)
# [*] Execution Mode   : Mock/Local Test (CPU/Fast)
# [*] Checkpoint Dir   : /kaggle/working/checkpoints
# [*] Output Dir       : /kaggle/working/output
# ===========================================================================
#
# >>> [PHASE 1] NẠP DỮ LIỆU & BÓC TÁCH MẨU KHẢO SÁT CÂN BẰNG NHÃN (STRATIFIED SLICING)...
#
# >>> [PHASE 2] XÂY DỰNG INDEX L2 & GÁN MẪU VÍ DỤ DEMONSTRATION (HYBRID RERANKING)...
# vocab.json: 703kB [00:00, 22.4MB/s]
# 2026-08-21 02:52:59,462 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/merges.txt "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 02:52:59,463 - WARNING - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 02:52:59,478 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/merges.txt "HTTP/1.1 200 OK"
# 2026-08-21 02:52:59,495 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/merges.txt "HTTP/1.1 200 OK"
# merges.txt: 294kB [00:00, 57.2MB/s]
# 2026-08-21 02:52:59,521 - INFO - Khởi tạo RobertaTokenizer thành công từ direct vocab/merges.
# 2026-08-21 02:53:01,121 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 02:53:01,137 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/config.json "HTTP/1.1 200 OK"
# 2026-08-21 02:53:01,154 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/config.json "HTTP/1.1 200 OK"
# config.json: 1.57kB [00:00, 1.60MB/s]
# 2026-08-21 02:53:01,203 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-08-21 02:53:01,257 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 02:53:01,273 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/config.json "HTTP/1.1 200 OK"
# 2026-08-21 02:53:01,314 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 2026-08-21 02:53:01,355 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 2026-08-21 02:53:01,402 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# 2026-08-21 02:53:01,490 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/xet-read-token/02cd2d31bb7c6d0e4d91156167b2de044989c733 "HTTP/1.1 200 OK"
# pytorch_model.bin: 100%|██████████████████████| 892M/892M [00:08<00:00, 109MB/s]
# 2026-08-21 02:53:09,761 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 2026-08-21 02:53:09,804 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base "HTTP/1.1 200 OK"
# 2026-08-21 02:53:09,866 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/commits/main "HTTP/1.1 200 OK"
# Loading weights: 100%|█| 100/100 [00:00<00:00, 3341.57it/s, Materializing param=
# The tied weights mapping and config for this model specifies to tie shared.weight to encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# T5EncoderModel LOAD REPORT from: Salesforce/codet5-base
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-08-21 02:53:09,936 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/discussions?p=0 "HTTP/1.1 200 OK"
# 2026-08-21 02:53:09,995 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/commits/refs%2Fpr%2F5 "HTTP/1.1 200 OK"
# 2026-08-21 02:53:10,039 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/refs%2Fpr%2F5/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 2026-08-21 02:53:10,084 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/refs%2Fpr%2F5/model.safetensors "HTTP/1.1 302 Found"
# 2026-08-21 02:53:10,122 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/xet-read-token/fcedbb79ad3190afe5a987160e044f23d1a7c20c "HTTP/1.1 200 OK"
# model.safetensors:   0%|                             | 0.00/892M [00:00<?, ?B/s]2026-08-21 02:53:10,403 - INFO - ✓ Nạp mô hình CodeT5 (Salesforce/codet5-base) thành công trên thiết bị cuda!
# 2026-08-21 02:53:10,404 - INFO - Đang xây dựng Index cho 50 mẫu huấn luyện...
# model.safetensors:   0%|                             | 0.00/892M [00:01<?, ?B/s]2026-08-21 02:53:11,505 - INFO - Xây dựng xong Index ma trận vector với kích thước: (50, 768)
# 2026-08-21 02:53:11,505 - INFO - Đang tiến hành truy xuất và gán mẫu In-Context Demonstration cho 20 mẫu Test...
# model.safetensors:  10%|██                   | 85.0M/892M [00:01<00:01, 425MB/s]2026-08-21 02:53:11,849 - INFO - Hoàn tất quy trình Retrieval Engine. Tự động gán trường 'example' cho 100% mẫu kiểm thử.
# 2026-08-21 02:53:11,850 - INFO - Môi trường Local/Test: Kích hoạt chế độ Intelligent Mock LLM Evaluator để test tốc độ cao.
# 2026-08-21 02:53:11,850 - INFO - Khởi tạo phiên chạy mới. File Checkpoint mới sẽ được lưu tại: /kaggle/working/checkpoints/checkpoint_kaggle_warmup_dryrun.jsonl
# 2026-08-21 02:53:11,850 - INFO - Bắt đầu quy trình Đánh Giá (Evaluator) cho 20 mẫu [Experiment: kaggle_warmup_dryrun]...
#
# >>> [PHASE 3] THỰC THI SUY LUẬN AI EVALUATOR & TỰ PHỤC HỒI CHECKPOINTING...
#
# Evaluating:   0%|                                    | 0/20 [00:00<?, ?sample/s]
# Acc: 100.0% | ID: mock_0:   0%|                      | 0/20 [00:00<?, ?sample/s]
# Acc: 100.0% | ID: mock_0:   5%|▋             | 1/20 [00:00<00:05,  3.72sample/s]
# Acc: 50.0% | ID: mock_1:   5%|▊              | 1/20 [00:00<00:05,  3.72sample/s]
# Acc: 66.7% | ID: mock_2:   5%|▊              | 1/20 [00:00<00:05,  3.72sample/s]
# Acc: 50.0% | ID: mock_3:   5%|▊              | 1/20 [00:00<00:05,  3.72sample/s]
# Acc: 60.0% | ID: mock_4:   5%|▊              | 1/20 [00:00<00:05,  3.72sample/s]
# Acc: 50.0% | ID: mock_5:   5%|▊              | 1/20 [00:00<00:05,  3.72sample/s]
# Acc: 50.0% | ID: mock_5:  30%|████▌          | 6/20 [00:00<00:00, 18.41sample/s]
# Acc: 57.1% | ID: mock_6:  30%|████▌          | 6/20 [00:00<00:00, 18.41sample/s]
# Acc: 50.0% | ID: mock_7:  30%|████▌          | 6/20 [00:00<00:00, 18.41sample/s]
# Acc: 55.6% | ID: mock_8:  30%|████▌          | 6/20 [00:00<00:00, 18.41sample/s]
# Acc: 50.0% | ID: mock_9:  30%|████▌          | 6/20 [00:00<00:00, 18.41sample/s]
# Acc: 54.5% | ID: mock_10:  30%|████▏         | 6/20 [00:00<00:00, 18.41sample/s]
# Acc: 54.5% | ID: mock_10:  55%|███████▏     | 11/20 [00:00<00:00, 26.74sample/s]
# Acc: 50.0% | ID: mock_11:  55%|███████▏     | 11/20 [00:00<00:00, 26.74sample/s]
# Acc: 53.8% | ID: mock_12:  55%|███████▏     | 11/20 [00:00<00:00, 26.74sample/s]
# Acc: 50.0% | ID: mock_13:  55%|███████▏     | 11/20 [00:00<00:00, 26.74sample/s]
# Acc: 53.3% | ID: mock_14:  55%|███████▏     | 11/20 [00:00<00:00, 26.74sample/s]
# Acc: 50.0% | ID: mock_15:  55%|███████▏     | 11/20 [00:00<00:00, 26.74sample/s]
# Acc: 50.0% | ID: mock_15:  80%|██████████▍  | 16/20 [00:00<00:00, 31.62sample/s]
# Acc: 52.9% | ID: mock_16:  80%|██████████▍  | 16/20 [00:00<00:00, 31.62sample/s]
# model.safetensors:  18%|███▉                  | 161M/892M [00:02<00:05, 144MB/s]
# Acc: 52.6% | ID: mock_18:  80%|██████████▍  | 16/20 [00:00<00:00, 31.62sample/s]
# Acc: 50.0% | ID: mock_19: 100%|█████████████| 20/20 [00:00<00:00, 27.42sample/s]
# 2026-08-21 02:53:12,581 - INFO - [✓] Đã xuất báo cáo chi tiết định dạng JSON tại: /kaggle/working/output/results_kaggle_warmup_dryrun.json
# 2026-08-21 02:53:12,581 - INFO - [✓] Đã xuất báo cáo đối chiếu nhãn CSV tại: /kaggle/working/output/summary_kaggle_warmup_dryrun.csv
#
# >>> [PHASE 4] ĐO LƯỜNG CHỈ SỐ AN NINH MẠNG & XUẤT BÁO CÁO NGHIỆM THU...
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# |  BẢNG BÁO CÁO KẾT QUẢ ĐÁNH GIÁ GRACE - [Mock Dry-Run E2E    ]  |
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# | - Tổng số mẫu đánh giá (Total Samples): 20                      |
# | - F1-SCORE (Chỉ số quyết định):         0.6667                  |
# | - Precision (Độ chính xác báo lỗi):     0.5                     |
# | - Recall (Độ phủ phát hiện lỗ hổng):    1.0                     |
# | - Accuracy (Tỉ lệ đúng toàn cục):       0.5                     |
# -----------------------------------------------------------------
# | MA TRẬN NHẦM LẪN (CONFUSION MATRIX):                              |
# |   [+] True Positive  (Đoán đúng Có lỗi):  10                    |
# |   [-] False Negative (Bỏ sót Lỗ hổng):   0                     |
# |   [+] True Negative  (Đoán đúng An toàn): 0                     |
# |   [-] False Positive (Báo động Giả):      10                    |
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# ===========================================================================
# 🎉 HOÀN THÀNH QUY TRÌNH GRACE END-TO-END PIPELINE! (Thời gian tổng: 0.69 phút)
# ===========================================================================
#
# model.safetensors: 100%|██████████████████████| 892M/892M [00:07<00:00, 124MB/s]

# %% [markdown]
# ## Bước 3: Khởi Chạy Thực Nghiệm Trí Tuệ Nhân Tạo Trên Bộ Dữ Liệu DEVIGN
# Kết nối tới **FPT AI Factory API** (DeepSeek-V4-Flash) để đánh giá lỗ hổng bảo mật trên 5% dataset thực tế **DetectVul/devign**.
#
# *(Lưu ý: Bạn cần khai báo biến `FPT_API_KEY` và `FPT_BASE_URL` trong Kaggle Secrets (Add-ons -> Secrets) trước khi chạy. Nhờ cơ chế Checkpointing JSONL, nếu phiên làm việc bị timeout, bạn chỉ cần bấm chạy lại cell này, hệ thống sẽ tiếp tục tại đúng mẫu trước đó!)*

# %%
# !python run_pipeline.py --dataset DetectVul/devign --sample_ratio 0.05 --experiment_name devign_openweights_5pct
# Out:
# 2026-08-21 02:53:20,583 - INFO - Đang kết nối tải dataset 'DetectVul/devign' từ Hugging Face Hub...
# 2026-08-21 02:53:20,583 - INFO - Phát hiện file dữ liệu đã trích xuất đồ thị CPG cục bộ: data/processed/devign_train_processed.json. Đang nạp...
# 2026-08-21 02:53:59,880 - INFO - Nạp thành công 21854 mẫu đã có đầy đủ đồ thị Joern từ devign_train_processed.json.
# 2026-08-21 02:54:00,507 - INFO - Trích xuất 5.0% dataset: Tổng 1091 mẫu (500 Vulnerable, 591 Safe) từ gốc 21854 mẫu.
# 2026-08-21 02:54:03,068 - INFO - Phát hiện file dữ liệu đã trích xuất đồ thị CPG cục bộ: data/processed/devign_test_processed.json. Đang nạp...
# 2026-08-21 02:54:07,473 - INFO - Nạp thành công 2732 mẫu đã có đầy đủ đồ thị Joern từ devign_test_processed.json.
# 2026-08-21 02:54:07,478 - INFO - Trích xuất 5.0% dataset: Tổng 135 mẫu (62 Vulnerable, 73 Safe) từ gốc 2732 mẫu.
# 2026-08-21 02:54:07,740 - INFO - Hoàn tất chuẩn bị dữ liệu -> Train index: 1091 mẫu | Test eval: 135 mẫu.
# 2026-08-21 02:54:14,713 - INFO - NumExpr defaulting to 4 threads.
# 2026-08-21 02:54:15,361 - INFO - Đang nạp mô hình Salesforce/codet5-base trên thiết bị cuda...
# 2026-08-21 02:54:15,490 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 02:54:15,506 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/vocab.json "HTTP/1.1 200 OK"
# 2026-08-21 02:54:15,546 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/merges.txt "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 02:54:15,546 - WARNING - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 02:54:15,561 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/merges.txt "HTTP/1.1 200 OK"
# 2026-08-21 02:54:15,562 - INFO - Khởi tạo RobertaTokenizer thành công từ direct vocab/merges.
# 2026-08-21 02:54:16,126 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 02:54:16,142 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/config.json "HTTP/1.1 200 OK"
# 2026-08-21 02:54:16,184 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-08-21 02:54:16,199 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/codet5-base/02cd2d31bb7c6d0e4d91156167b2de044989c733/config.json "HTTP/1.1 200 OK"
# 2026-08-21 02:54:16,240 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 2026-08-21 02:54:16,280 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 2026-08-21 02:54:16,321 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# 2026-08-21 02:54:16,361 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 2026-08-21 02:54:16,402 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base "HTTP/1.1 200 OK"
#
# ###########################################################################
# ###  GRACE VULNERABILITY DETECTION - END-TO-END ORCHESTRATION PIPELINE  ###
# ###########################################################################
# [*] Experiment Name  : devign_openweights_5pct
# [*] Target Dataset   : DetectVul/devign (Sample Ratio: 5.0%)
# [*] Execution Mode   : Full Open-Weights LLM (gemma-4-26B-A4B-it on GPU)
# [*] Checkpoint Dir   : /kaggle/working/checkpoints
# [*] Output Dir       : /kaggle/working/output
# ===========================================================================
#
# >>> [PHASE 1] NẠP DỮ LIỆU & BÓC TÁCH MẨU KHẢO SÁT CÂN BẰNG NHÃN (STRATIFIED SLICING)...
#
# >>> [PHASE 2] XÂY DỰNG INDEX L2 & GÁN MẪU VÍ DỤ DEMONSTRATION (HYBRID RERANKING)...
# Loading weights:  88%|▉| 88/100 [00:00<00:00, 3060.80it/s, Materializing param=e2026-08-21 02:54:16,461 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/commits/main "HTTP/1.1 200 OK"
# Loading weights: 100%|█| 100/100 [00:00<00:00, 2789.27it/s, Materializing param=
# The tied weights mapping and config for this model specifies to tie shared.weight to encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# T5EncoderModel LOAD REPORT from: Salesforce/codet5-base
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-08-21 02:54:16,519 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/discussions?p=0 "HTTP/1.1 200 OK"
# 2026-08-21 02:54:16,575 - INFO - HTTP Request: GET https://huggingface.co/api/models/Salesforce/codet5-base/commits/refs%2Fpr%2F5 "HTTP/1.1 200 OK"
# 2026-08-21 02:54:16,614 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/refs%2Fpr%2F5/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 2026-08-21 02:54:16,658 - INFO - HTTP Request: HEAD https://huggingface.co/Salesforce/codet5-base/resolve/refs%2Fpr%2F5/model.safetensors "HTTP/1.1 302 Found"
# 2026-08-21 02:54:16,893 - INFO - ✓ Nạp mô hình CodeT5 (Salesforce/codet5-base) thành công trên thiết bị cuda!
# 2026-08-21 02:54:16,893 - INFO - Đang xây dựng Index cho 1091 mẫu huấn luyện...
# 2026-08-21 02:54:18,126 - INFO - Xây dựng xong Index ma trận vector với kích thước: (1091, 768)
# 2026-08-21 02:54:18,126 - INFO - Đang tiến hành truy xuất và gán mẫu In-Context Demonstration cho 135 mẫu Test...
# 2026-08-21 02:54:20,649 - INFO - Hoàn tất quy trình Retrieval Engine. Tự động gán trường 'example' cho 100% mẫu kiểm thử.
# 2026-08-21 02:54:21,849 - INFO - Kết nối tới API: https://mkp-api.fptcloud.com với model gemma-4-26B-A4B-it...
# 2026-08-21 02:54:21,889 - INFO - Khởi tạo phiên chạy mới. File Checkpoint mới sẽ được lưu tại: /kaggle/working/checkpoints/checkpoint_devign_openweights_5pct.jsonl
# 2026-08-21 02:54:21,889 - INFO - Bắt đầu quy trình Đánh Giá (Evaluator) cho 135 mẫu [Experiment: devign_openweights_5pct]...
#
# >>> [PHASE 3] THỰC THI SUY LUẬN AI EVALUATOR & TỰ PHỤC HỒI CHECKPOINTING...
# Evaluating:   0%|                                   | 0/135 [00:00<?, ?sample/s]2026-08-21 02:54:23,230 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 100.0% | ID: id_25566:   1%|           | 1/135 [00:01<03:08,  1.40s/sample]2026-08-21 02:54:23,732 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 50.0% | ID: id_15373:   1%|▏           | 2/135 [00:01<01:55,  1.15sample/s]2026-08-21 02:54:24,223 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 33.3% | ID: id_11988:   2%|▎           | 3/135 [00:02<01:31,  1.44sample/s]2026-08-21 02:54:24,734 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 50.0% | ID: id_2820_:   3%|▎           | 4/135 [00:02<01:21,  1.61sample/s]2026-08-21 02:54:25,212 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 60.0% | ID: id_11328:   4%|▍           | 5/135 [00:03<01:14,  1.75sample/s]2026-08-21 02:54:25,727 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 66.7% | ID: id_686_l:   4%|▌           | 6/135 [00:03<01:11,  1.81sample/s]2026-08-21 02:54:26,238 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 71.4% | ID: id_4879_:   5%|▌           | 7/135 [00:04<01:08,  1.86sample/s]2026-08-21 02:54:26,738 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 75.0% | ID: id_9301_:   6%|▋           | 8/135 [00:04<01:06,  1.90sample/s]2026-08-21 02:54:27,231 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc:
- INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 58.0% | ID: id_25310:  97%|█████████▋| 131/135 [02:08<00:02,  1.82sample/s]2026-08-21 02:56:30,920 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 57.6% | ID: id_2832_:  98%|█████████▊| 132/135 [02:09<00:01,  1.88sample/s]2026-08-21 02:56:31,338 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 57.9% | ID: id_20433:  99%|█████████▊| 133/135 [02:09<00:00,  2.01sample/s]2026-08-21 02:56:31,830 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 58.2% | ID: id_12329:  99%|█████████▉| 134/135 [02:09<00:00,  2.02sample/s]2026-08-21 02:56:32,330 - INFO - HTTP Request: POST https://mkp-api.fptcloud.com/chat/completions "HTTP/1.1 200 OK"
# Acc: 57.8% | ID: id_24141: 100%|██████████| 135/135 [02:10<00:00,  1.03sample/s]
# 2026-08-21 02:56:32,387 - INFO - [✓] Đã xuất báo cáo chi tiết định dạng JSON tại: /kaggle/working/output/results_devign_openweights_5pct.json
# 2026-08-21 02:56:32,388 - INFO - [✓] Đã xuất báo cáo đối chiếu nhãn CSV tại: /kaggle/working/output/summary_devign_openweights_5pct.csv
#
# >>> [PHASE 4] ĐO LƯỜNG CHỈ SỐ AN NINH MẠNG & XUẤT BÁO CÁO NGHIỆM THU...
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# |  BẢNG BÁO CÁO KẾT QUẢ ĐÁNH GIÁ GRACE - [DetectVul/devign    ]  |
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# | - Tổng số mẫu đánh giá (Total Samples): 135                     |
# | - F1-SCORE (Chỉ số quyết định):         0.5043                  |
# | - Precision (Độ chính xác báo lỗi):     0.5472                  |
# | - Recall (Độ phủ phát hiện lỗ hổng):    0.4677                  |
# | - Accuracy (Tỉ lệ đúng toàn cục):       0.5778                  |
# -----------------------------------------------------------------
# | MA TRẬN NHẦM LẪN (CONFUSION MATRIX):                              |
# |   [+] True Positive  (Đoán đúng Có lỗi):  29                    |
# |   [-] False Negative (Bỏ sót Lỗ hổng):   33                    |
# |   [+] True Negative  (Đoán đúng An toàn): 49                    |
# |   [-] False Positive (Báo động Giả):      24                    |
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# ===========================================================================
# 🎉 HOÀN THÀNH QUY TRÌNH GRACE END-TO-END PIPELINE! (Thời gian tổng: 3.20 phút)
# ===========================================================================

# %% [markdown]
# ## Bước 4: Khởi Chạy Thực Nghiệm Mở Rộng Trên Bộ Dữ Liệu REVEAL
# Thử nghiệm trên bộ dataset Reveal nhằm kiểm chứng khả năng tổng quát hóa (Generalizability) của phương pháp GRACE.

# %% [markdown]
# ## Bước 5: Phỏng Đoán Báo Cáo Kết Quả Tự Động Xuất Xưởng (Artifact Inspection)
# Trình diễn các file kết quả JSON và CSV đã được ghi xuống thư mục `output/`.

# %%
import os
import pandas as pd
from pathlib import Path

output_dir = Path('/kaggle/working/output') if os.path.exists('/kaggle/working') else Path('./output')
print('Danh sách tệp nghiệm thu thu được từ hệ thống:')
if output_dir.exists():
    for f in output_dir.glob('*.*'):
        print('  ->', f.name)
else:
    print('Thư mục output chưa được tạo.')
# Out:
# Danh sách tệp nghiệm thu thu được từ hệ thống:
#   -> results_devign_openweights_5pct.json
#   -> summary_devign_openweights_5pct.csv
#   -> summary_kaggle_warmup_dryrun.csv
#   -> results_kaggle_warmup_dryrun.json
